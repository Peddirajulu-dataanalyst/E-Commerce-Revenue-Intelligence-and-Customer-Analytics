# %%
#load data
import pandas as pd
orders = pd.read_csv(r"D:\python project files\E-commerce Revenue Intelligence and Customer Analytics\data\raw\orders.csv")
customers = pd.read_csv(r"D:\python project files\E-commerce Revenue Intelligence and Customer Analytics\data\raw\customers.csv")
products = pd.read_csv(r"D:\python project files\E-commerce Revenue Intelligence and Customer Analytics\data\raw\products.csv")
returns = pd.read_csv(r"D:\python project files\E-commerce Revenue Intelligence and Customer Analytics\data\raw\returns.csv")

# %%
#dataset shape
customers.shape
# Out:
# (10000, 6)

# %%
returns.shape
# Out:
# (15000, 3)

# %%
products.shape
# Out:
# (500, 6)

# %%
orders.shape
# Out:
# (200000, 10)

# %%
#data types
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order_id     200000 non-null  int64
#  1   order_date   200000 non-null  object
#  2   customer_id  200000 non-null  int64
#  3   product_id   200000 non-null  int64
#  4   quantity     200000 non-null  int64
#  5   sales        200000 non-null  float64
#  6   discount     200000 non-null  float64
#  7   profit       200000 non-null  float64
#  8   region       200000 non-null  object
#  9   channel      200000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 15.3+ MB

# %%
#missing values
orders.isnull().sum()
# Out:
# order_id       0
# order_date     0
# customer_id    0
# product_id     0
# quantity       0
# sales          0
# discount       0
# profit         0
# region         0
# channel        0
# dtype: int64

# %%
#summary statistics
orders.describe()
# Out:
#             order_id    customer_id     product_id       quantity  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean   100000.500000    4992.028555     250.234330       2.500030
# std     57735.171256    2889.982680     144.324926       1.116784
# min         1.000000       1.000000       1.000000       1.000000
# 25%     50000.750000    2480.000000     125.000000       2.000000
# 50%    100000.500000    4993.000000     250.000000       2.000000
# 75%    150000.250000    7484.000000     375.000000       3.000000
# max    200000.000000   10000.000000     500.000000       4.000000
#
#                sales       discount         profit
# count  200000.000000  200000.000000  200000.000000
# mean      260.379247       0.150105      45.600982
# std       138.403411       0.086678      32.308614
# min        20.000000       0.000000       1.020000
# 25%       140.567500       0.080000      19.540000
# 50%       260.680000       0.150000      38.030000
# 75%       380.090000       0.220000      65.960000
# max       500.000000       0.300000     149.720000

# %%
#profit distribution
orders['profit'].hist()
# Out:
# <Axes: >

# %%
#Revenue distribution
orders['sales'].hist
# Out:
# <bound method hist_series of 0         249.09
# 1         323.70
# 2         343.61
# 3          91.61
# 4         137.73
#            ...
# 199995    430.08
# 199996    112.78
# 199997    427.98
# 199998    150.07
# 199999    174.85
# Name: sales, Length: 200000, dtype: float64>

# %%
#orders per customer
orders.groupby('customer_id').size().describe()
# Out:
# count    10000.000000
# mean        20.000000
# std          4.377775
# min          6.000000
# 25%         17.000000
# 50%         20.000000
# 75%         23.000000
# max         38.000000
# dtype: float64

# %%
#Category revenue
merged = orders.merge(products,on='product_id')
merged.groupby('category')['sales'].sum()
# Out:
# category
# Furniture          17075350.35
# Office Supplies    17828024.26
# Technology         17172474.72
# Name: sales, dtype: float64

# %%
#channel distribution
orders['channel'].value_counts()
# Out:
# channel
# Retail    100159
# Online     99841
# Name: count, dtype: int64
